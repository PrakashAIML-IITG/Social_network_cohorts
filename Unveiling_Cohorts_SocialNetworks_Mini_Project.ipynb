# %% [markdown]
# # PROJECT TITLE: Unveiling Segments in Social Networks

# %% [markdown]
# ## Problem Statement ##
#
# Businesses face significant challenges in understanding and leveraging the complex dynamics of social media interactions and community structures to engage effectively with their target audiences.
#
# **Objective:**
#
#   Develop a system that automatically analyzes social media networks to identify and cluster communities, providing actionable insights that help businesses:
#
#   **Audience Segmentation:** Identify clusters of users with similar interests, behaviors, or demographics for targeted marketing strategies.
#
#   **Influencer Identification**: Discover influential users within specific communities to enhance influencer marketing efforts.
#
#   **Community Engagement**: Understand social network structures and user interactions to foster genuine community engagement and build brand trust.

# %% [markdown]
# **Machine Learning Problem**:
#
#   In this problem, we aim to build Machine Learning models in order to cluster several social media users together. This is an unsupervised learning problem.  We are going to work with a special kind of data called **Graph Data.**
#
# **About The Dataset:**
#
#   graph data represents relationships between entities. Imagine social networks like Facebook or Twitter, where users are connected to each other through friendships or follows. E**ach user is a node in the graph**, and the **connections between them are edges**. This structure allows us to model complex relationships and interactions in a way that traditional tabular data cannot capture.
#
# **Fundamentals of Graph Representation:**
#
#   **Nodes (Vertices):** These are the entities in our graph. In a social network, nodes could represent users, while in a transportation network, they could represent cities or airports.
#
#   **Edges (Links):** These represent the relationships between nodes. In a social network, edges could indicate friendships or follows, while in a transportation network, they could represent roads or flight routes.
#
#   **Attributes:** Nodes and edges can have associated attributes that provide additional information. For example, a user node in a social network could have attributes such as age, location, or interests.

# %% [markdown]
# ## Approach to solve the Problem:
#
# 1. **Data Collection** and  **Graph Representation**: Load the txt file as Graph. Instructions given in the next section
#
# 2. **Feature Engineering:** Derive informative features from the loaded graph
#
# 3. **Data Preparation:** Prepare the feature-engineered data for clustering. This may involve normalization or scaling of the features, handling missing values, or any other necessary preprocessing steps to ensure the data is suitable for clustering algorithms.
#
# 4. **Exploratory Data Analysis(EDA):** Using charts and visualizations, explore patterns and summarize the characteristics of the dataset.
#
# 5. **Clustering**: Apply clustering algorithms to group nodes based on their shared structural properties. Consider techniques such as k-means, hierarchical clustering, DBSCAN etc. Experiment with different parameter settings and evaluation metrics to find the most appropriate clustering approach for the given problem.
#
#
# 6. **Evaluation:** Assess the quality of the generated clusters by employing appropriate evaluation metrics. Evaluate the clustering performance using metrics such as the silhouette score, Calinski-Harabasz index, and Davies-Bouldin index.
#
#
# 7. **Interpretation and Analysis:** Analyze the obtained clusters to gain insights into the structural properties shared by the nodes. Explore the relationships between clusters, identify any patterns or anomalies, and interpret the results in the context of the problem domain.
#
#
# 8. **Refinement and Iteration**: Fine-tune the feature engineering techniques, clustering algorithms, and parameter settings based on the results and insights obtained. Iterate through the steps to improve the clustering performance and gain a deeper understanding of the graph's structural properties.
#
#
# 9. **Documentation and Reporting:** Document the methodology, results, and findings of the analysis process. Prepare a comprehensive report or presentation summarizing the problem, approach, experiments conducted, and conclusions drawn. Communicate the insights and potential applications of the analysis.

# %% [markdown]
# ## LOAD THE LIBRARIES:

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-3.6.1-py3-none-any.whl (380 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 3.6 MB/s eta 0:00:00
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 25.6 MB/s eta 0:00:00
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.8.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.30)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.1)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (2.1.5)
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.5 alembic-1.13.1 colorlog-6.8.2 optuna-3.6.1

# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from networkx.algorithms.connectivity import local_node_connectivity
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
import optuna
from sklearn.model_selection import GridSearchCV
import warnings
warnings.simplefilter("ignore")

# %%
## Additional step may or may not required depending upon the IDE you are using
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### STEP1: DATA COLLECTION & GRAPH REPRESENTAION ###

# %%
G = nx.read_edgelist('/content/drive/MyDrive/IK_mini_Project/facebook_combined.txt', create_using=nx.Graph(), nodetype=int)

# %% [markdown]
# ### checking How the graph looks like (optional step)

# %%
nx.draw(G, with_labels=True, node_color='lightblue', edge_color='gray')
plt.show()

# %% [markdown]
# ### STEP2: FEATURE ENGINEERING ###

# %%
# Derive information from the loaded graph

nodes = list(G.nodes()) #Extract the node(converting the nodes of the graph into a list)

features = pd.DataFrame(index=nodes) # create a dataframe to hold the features(add computed features as columns.)

features['degree'] = [G.degree(n) for n in nodes] # Compute node degree(calculates the degree of each node and stores it in the DataFrame under the column 'degree'.)

"""
Node Degree: The degree of a node is the number of edges connected to it.It is a fundamental measure of a node's connectivity within the graph.

Local Feature: The degree is a local feature because it pertains to the immediate connectivity of a node.
It's computed by counting the number of direct connections (or edges) a node has.

Usage in Clustering: Knowing the degree helps in understanding the node's prominence in its local neighborhood, which can be crucial for clustering algorithms that group nodes based on their local structural properties.

The degree of a node is calculated using G.degree(n), which gives the number of edges connected to node n.
By iterating over each node and computing its degree, we populate the 'degree' column in the DataFrame.
This feature is essential for understanding the local structure around each node and provides a basis for further feature engineering and analysis

"""
# Out:
# "\nNode Degree: The degree of a node is the number of edges connected to it.It is a fundamental measure of a node's connectivity within the graph.\n\nLocal Feature: The degree is a local feature because it pertains to the immediate connectivity of a node.\nIt's computed by counting the number of direct connections (or edges) a node has.\n\nUsage in Clustering: Knowing the degree helps in understanding the node's prominence in its local neighborhood, which can be crucial for clustering algorithms that group nodes based on their local structural properties.\n\nThe degree of a node is calculated using G.degree(n), which gives the number of edges connected to node n.\nBy iterating over each node and computing its degree, we populate the 'degree' column in the DataFrame.\nThis feature is essential for understanding the local structure around each node and provides a basis for further feature engineering and analysis\n\n"

# %%
# Calculate clustering coeeficient
"""
The clustering coefficient tells how likely two friends (neighbors) of a particular user (node) are also friends with each other.
This measures the extent to which a node's neighbors are connected to each other, indicating the presence of local clusters or cliques
"""

features['clustering'] = [nx.clustering(G, n) for n in nodes]

# calculating betweeness centrality:

"""
Betweenness centrality is a measure of a node's influence or control over the flow of information or communication within a network.
It essentially tells you how often a node lies on the shortest paths between other nodes in the network
in ortherwords, This measures the extent to which a node's neighbors are connected to each other, indicating the presence of local clusters or cliques
n - represents each node as iterator
"""
betweenness = nx.betweenness_centrality(G)
features['betweenness'] = [betweenness[n] for n in nodes]

# Closeness Centrality:
"""
Closeness centrality measures how "close" a node (user) is to all other nodes in the network.
It essentially calculates the average distance (shortest path length) between a user and every other user in the network.
Well-connected, easy to reach others and Identifying potential information spreaders, analyzing overall information flow
"""

closeness = nx.closeness_centrality(G)
features['closeness'] = [closeness[n] for n in nodes]

# Average Neighbor Degree
"""
is a measure that captures the average degree of the node's neighbors. For a given node, it reflects the mean number of connections that its neighbors have.
The average neighbor degree gives an indication of the connectivity level of the neighborhood surrounding a node.
If a node has a high average neighbor degree, it means that its neighbors are well-connected, suggesting a densely connected local structure

"""
avg_neighbor_degree = nx.average_neighbor_degree(G)
features['avg_neighbor_degree'] = [avg_neighbor_degree[n] for n in nodes]

# PageRank
"""
PageRank is used to measure the importance or influence of nodes within a graph.
It assigns a probability distribution to each node representing the likelihood of landing on that node by randomly traversing the graph.
PageRank scores represent the importance or influence of nodes in the network. A high PageRank score indicates that a node is important or influential.
"""
pagerank = nx.pagerank(G)
features['pagerank'] = [pagerank[n] for n in nodes]

# 2-Hop Neighbor Degree
"""
The 2-hop neighbor degree of a node is the sum of the degrees of all nodes that are reachable within two steps (or hops) from the given node, excluding the node itself
it provides information about the node’s indirect influence and the connectivity of its neighborhood. It indicates how well-connected the node's neighbors' neighbors are.

"""
two_hop_degrees = []
for n in nodes:
    two_hop_neighbors = set(nx.single_source_shortest_path_length(G, n, cutoff=2).keys())
    two_hop_neighbors.discard(n)  # Remove the node itself
    two_hop_degree = sum([G.degree(neigh) for neigh in two_hop_neighbors])
    two_hop_degrees.append(two_hop_degree)
features['2hop_degree'] = two_hop_degrees

# 3-Hop Neighbor Degree
"""
The 3-hop neighbor degree of a node is the sum of the degrees of all nodes that are reachable within three steps (or hops) from the given node, excluding the node itself.
It provides a broader view of the node’s extended neighborhood. It gives insight into the connectivity pattern at a larger scale around the node.
"""

three_hop_degrees = []
for n in nodes:
    three_hop_neighbors = set(nx.single_source_shortest_path_length(G, n, cutoff=3).keys())
    three_hop_neighbors.discard(n)  # Remove the node itself
    three_hop_degree = sum([G.degree(neigh) for neigh in three_hop_neighbors])
    three_hop_degrees.append(three_hop_degree)
features['3hop_degree'] = three_hop_degrees

# %% [markdown]
# ##STEP3: Data Preparation

# %%
# Data normalization
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# %%
features.head()
# Out:
#    degree  clustering   betweenness  closeness  avg_neighbor_degree  pagerank  \
# 0     347    0.041962  1.463059e-01   0.353343            18.959654  0.006290
# 1      17    0.419118  2.783274e-06   0.261376            48.235294  0.000236
# 2      10    0.888889  7.595021e-08   0.261258            49.900000  0.000203
# 3      17    0.632353  1.685066e-06   0.261376            59.764706  0.000226
# 4      10    0.866667  1.840332e-07   0.261258            42.600000  0.000238
#
#    2hop_degree  3hop_degree
# 0        75400       162874
# 1         6909        75730
# 2         6916        75737
# 3         6909        75730
# 4         6916        75737

# %% [markdown]
# ## STEP4: EXPLORATORY DATA ANALYSIS (EDA)

# %%
# Set up the visualization parameters
sns.set(style="whitegrid")
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Histograms
sns.histplot(features['degree'], kde=True, ax=axes[0, 0])
axes[0, 0].set_title('Degree Distribution')

sns.histplot(features['clustering'], kde=True, ax=axes[0, 1])
axes[0, 1].set_title('Clustering Coefficient Distribution')

sns.histplot(features['avg_neighbor_degree'], kde=True, ax=axes[1, 0])
axes[1, 0].set_title('Average Neighbor Degree Distribution')

sns.histplot(features['pagerank'], kde=True, ax=axes[1, 1])
axes[1, 1].set_title('Pagerank Distribution')

plt.tight_layout()
plt.show()

# Scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(data=features, x='degree', y='pagerank', hue='clustering', palette='viridis')
plt.title('Degree vs. Pagerank (Color: Clustering Coefficient)')
plt.xlabel('Degree')
plt.ylabel('Pagerank')
plt.legend(title='Clustering')
plt.show()

# Correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(features.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
# Create visualizations
features_to_plot = ['degree', 'clustering', 'betweenness', 'closeness', 'avg_neighbor_degree', 'pagerank', '2hop_degree', '3hop_degree']

for feature in features_to_plot:
    plt.figure(figsize=(8, 6))
    plt.hist(features[feature])
    plt.xlabel(feature)
    plt.ylabel('Frequency')
    plt.title(f'Distribution of {feature}')
    plt.grid(True)
    plt.show()

# Additional visualizations (scatter plots)
scatter_features = [('degree', 'clustering'), ('degree', 'betweenness'), ('degree', 'pagerank')]
for feature1, feature2 in scatter_features:
    plt.figure(figsize=(8, 6))
    plt.scatter(features[feature1], features[feature2])  # Use feature2 from the current tuple
    plt.xlabel(feature1)
    plt.ylabel(feature2)
    plt.grid(True)
    plt.show()

# %%
# Scatter features (replace with your desired features)
scatter_features = [('degree', 'clustering'), ('degree', 'betweenness'), ('degree', 'pagerank'), ('betweenness', 'pagerank')]

# Create subplots (1 row, 3 columns)
fig, axes = plt.subplots(1, 4, figsize=(15, 6))  # Adjust figsize as needed

# Iterate through scatter features and create plots on subplots
for i, (feature1, feature2) in enumerate(scatter_features):
    axes[i].scatter(features[feature1], features[feature2])
    axes[i].set_xlabel(feature1)
    axes[i].set_ylabel(feature2)
    axes[i].title.set_text(f'Scatter Plot of {feature1} vs. {feature2}')
    axes[i].grid(True)



# Adjust layout (optional)
plt.tight_layout()

plt.show()

# %% [markdown]
# **INSIGHTES FROM degree Vs Clustering:**
#
#   Nodes with lower degrees tend to form tightly connected clusters or communities. This indicates a high level of local connectivity among nodes within these clusters, where users interact closely with their neighbors.
#
#   **for community structure**, The dense grouping of datapoints in the lower degree range may correspond to distinct communities or clusters within the network. These communities exhibit high clustering coefficients, indicating that nodes within each community have a high tendency to form connections with each other.
#
#   The presense of very few nodes in with a degree between 200 to 1000, suggests the existence of a small number of highly influential nodes or hubs with a large number of connections. These influential nodes may serve as bridges between different communities or as central figures within the network.
#
# **Betweenness vs Degree:**
#
#   The concentration of betweenness data points within the range of 0.0 to 0.1 for degrees in the range of 0-200 suggests that nodes within this degree range primarily contribute to local connectivity and have limited betweenness centrality in facilitating global information flow within the network.
#
# **Degree Vs PageRank:**
#
#   The presence of higher Pagerank values (0.004 to 0.007) for a few data points with degrees between 400-1000 suggests the existence of a small number of highly influential nodes or hubs in the network. Nodes with higher Pagerank values and higher degrees (400-1000) likely represent central figures or key influencers within the network. They may serve as pivotal points for information dissemination, opinion formation, or community coordination due to their extensive connections and engagement with other nodes.
#
#   The influential nodes with higher Pagerank values and higher degrees (400-1000) may act as bridge nodes connecting different parts of the network. They facilitate the flow of information and interactions between disparate communities or clusters, thereby promoting cohesion and integration within the network.
#
#    the predominance of low Pagerank values for nodes within the degree range of 0-200 reflects their limited influence and local engagement within niche communities or clusters within the network. While these nodes may not be highly central or influential on a global scale, they play important roles in sustaining community dynamics and fostering interactions within their respective communities.
#
#
#  **  Betweenness Vs PageRank:**
#
#    Nodes with higher betweenness centrality (0.2 to 0.5) and corresponding higher Pagerank values (0.004 to 0.007) likely act as bridge nodes or critical intermediaries in the network. These nodes serve as pivotal points for facilitating communication and information flow between different parts of the network, thereby enhancing its connectivity and cohesion
#
#    Nodes with higher Pagerank values and higher betweenness centrality represent influential figures with global reach and impact within the network. They have the ability to influence a wide range of nodes and communities, shaping the overall dynamics and evolution of the network.
#
#    Nodes with lower Pagerank values and lower betweenness centrality (0.0 to 0.15) primarily contribute to local connectivity within their immediate neighborhoods or communities.
#
#    In summary, the observation of higher Pagerank values for nodes with higher betweenness centrality suggests the presence of influential bridge nodes that play critical roles in connecting disparate parts of the network and shaping its overall structure and dynamics.

# %%
# Scatter features (replace with your desired features)
scatter_features = [('clustering', 'closeness'), ('avg_neighbor_degree', 'clustering'), ('3hop_degree', 'closeness'), ('2hop_degree', 'closeness')]

# Create subplots (1 row, 3 columns)
fig, axes = plt.subplots(1, 4, figsize=(15, 6))  # Adjust figsize as needed

# Iterate through scatter features and create plots on subplots
for i, (feature1, feature2) in enumerate(scatter_features):
    axes[i].scatter(features[feature1], features[feature2])
    axes[i].set_xlabel(feature1)
    axes[i].set_ylabel(feature2)
    axes[i].title.set_text(f'Scatter Plot of {feature1} vs. {feature2}')
    axes[i].grid(True)



# Adjust layout (optional)
plt.tight_layout()

plt.show()

# %% [markdown]
# **Clustering Vs Closeness:**
#
# The confusion matrix says both have strong coorelation.
#
# Nodes with higher clustering coefficients (0.4 to 1.0) and lower closeness centrality values (0.2 to 0.35) indicate the presence of densely interconnected clusters or communities within the network. These nodes are part of tightly knit groups where most neighbors are also connected to each other, resulting in high clustering coefficients. However, the closeness centrality values suggest that these clusters may not be efficiently connected to other parts of the network, implying a more localized pattern of connectivity.
#
#
# The few data points with higher closeness centrality values (>0.4) and lower clustering coefficients (0.0 to 0.2) represent nodes that act as bridges or connectors between different clusters or communities within the network. These nodes have shorter average path lengths to other nodes in the network, indicating their importance in facilitating global communication and information flow. This can create bridge nodes.
#
# **closeness Vs 3hop_degree:**
#
# Nodes with higher closeness centrality values (0.25 to 0.40) indicate that they are more centrally located and have shorter average distances to other nodes. The observation that these nodes have 3-hop neighbor degree samples ranging between 7500 to 17000 suggests that they serve as efficient communication hubs, with connections to a large number of nodes within a short number of hops. This indicates that these nodes are well-positioned to disseminate information quickly and effectively across the network.
#
# Nodes with lower closeness centrality values (<0.25) have fewer direct connections to other nodes and are located farther away from the majority of the network. The scarcity of 3-hop neighbor degree samples within the range of 0 to 1000 for these nodes suggests that they may be peripheral or isolated nodes within the network. These nodes are less central in terms of communication and may have limited influence or interaction with other nodes in the network.
#
# **2hop_degree Vs Closeness:**
#
# Between 2-hop degree and closeness centrality highlights the importance of central nodes in terms of connectivity and influence. Nodes with high closeness centrality and high 2-hop degrees are central hubs that play a crucial role in maintaining the network's connectivity and facilitating rapid information spread.
#
# For businesses, nodes with high closeness and high 2-hop degrees could be key targets for marketing campaigns and engagement efforts, as they are likely to have the most extensive reach and influence within the network

# %%
# Pairplot of the features
sns.pairplot(pd.DataFrame(scaled_features, columns=features.columns))
plt.show()

# %% [markdown]
# **Degree Distribution:**
#
# The degree distribution (number of connections per node) appears skewed, with a longer tail towards higher degrees. This suggests that a small number of nodes have many connections (hubs), while most nodes have a fewer connections.
#
# The high count of nodes with small degrees suggests that the network may be sparse, meaning that there are fewer connections between nodes compared to the total number of nodes in the network.
#
# **Clustering Coefficient Distribution:**
#
# The clustering coefficient distribution might indicate the presence of communities. If there are distinct peaks or clusters in the distribution, it suggests nodes tend to connect with others within the same community.
#
# **PageRank:**
#
# low Pagerank scores have high frequency counts suggests a decentralized distribution of influence within the social network, with opportunities for engagement and interaction across a diverse range of nodes.
#
# **Betweenness and Pagerank Distributions:**
#
# Both betweenness and pagerank distributions likely have a similar pattern to degree, with a skew towards lower values. This implies that most nodes don't lie on many shortest paths or have high importance based on incoming links. However, there might be a few prominent nodes with high betweenness and pagerank scores.
#
# **Closeness and Average Neighbor Degree Distributions:**
#
# The closeness distribution might show a peak at higher values, indicating that most nodes are relatively close (in terms of shortest path lengths) to other nodes in the network.
# The average neighbor degree distribution could be similar to the degree distribution, reflecting that nodes with many connections tend to have neighbors with many connections as well.
#
# **2-hop Degree and 3-hop Degree Distributions:**
#
# These distributions likely show an increasing trend as the hop count increases. This suggests that nodes can reach a significant portion of the network within 2 or 3 hops, implying a relatively small network diameter (maximum distance between any two nodes).
#
# **Scatter Plots:**
#
# Scatter plots of degree vs. other features (clustering, betweenness, pagerank) might reveal correlations. For example, a positive correlation between degree and betweenness could suggest that nodes with many connections are more likely to lie on shortest paths.

# %% [markdown]
# ##STEP5:CLUSTERING

# %%
# K-means
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(scaled_features)  # Use scaled features for fitting
cluster_labels_kmeans = kmeans.labels_

# Hierarchical clustering (Agglomerative)
ward_clustering = AgglomerativeClustering(n_clusters=3, linkage='ward')
ward_clustering.fit(scaled_features)  # Use scaled features for fitting
cluster_labels_ward = ward_clustering.labels_

# DBSCAN (adjust eps and min_samples as needed)
dbscan = DBSCAN(eps=0.5, min_samples=5)
dbscan.fit(scaled_features)  # Use scaled features for fitting
cluster_labels_dbscan = dbscan.labels_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# ## STEP6: EVALUATION

# %%
# Silhouette Score
print("Silhouette Score (K-Means):", silhouette_score(scaled_features, cluster_labels_kmeans).round(3))
print("Silhouette Score (Agglomerative):", silhouette_score(scaled_features, cluster_labels_ward ).round(3))
print("Silhouette Score (DBSCAN):", silhouette_score(scaled_features, cluster_labels_dbscan).round(3))
# Out:
# Silhouette Score (K-Means): 0.325
# Silhouette Score (Agglomerative): 0.314
# Silhouette Score (DBSCAN): 0.057

# %%
# Calinski-Harabasz Index
print("Calinski-Harabasz Index (K-Means):", calinski_harabasz_score(scaled_features, cluster_labels_kmeans).round(3))
print("Calinski-Harabasz Index (Agglomerative):", calinski_harabasz_score(scaled_features, cluster_labels_ward).round(3))
print("Calinski-Harabasz Index (DBSCAN):", calinski_harabasz_score(scaled_features, cluster_labels_dbscan).round(3))
# Out:
# Calinski-Harabasz Index (K-Means): 1622.528
# Calinski-Harabasz Index (Agglomerative): 1377.878
# Calinski-Harabasz Index (DBSCAN): 150.503

# %%
# Davies-Bouldin Index
print("Davies-Bouldin Index (K-Means):", davies_bouldin_score(scaled_features, cluster_labels_kmeans).round(3))
print("Davies-Bouldin Index (Agglomerative):", davies_bouldin_score(scaled_features, cluster_labels_ward).round(3))
print("Davies-Bouldin Index (DBSCAN):", davies_bouldin_score(scaled_features, cluster_labels_dbscan).round(3))
# Out:
# Davies-Bouldin Index (K-Means): 0.908
# Davies-Bouldin Index (Agglomerative): 0.806
# Davies-Bouldin Index (DBSCAN): 1.515

# %% [markdown]
# ### STEP:7-1: Interpretation and Analysis
# --------------------------------------------------[link text](https://)
#
# ## Combined Insights from All Metrics
#
# **K-Means Clustering:**
# ------------------------------------------
#
#   **Davies-Bouldin Index**: 0.908
#
#   S**ilhouette Score:** 0.325
#
#  **Calinski-Harabasz Index:** 1622.528
#
#   **Combined Interpretation:** K-Means performs well across all metrics, indicating that it forms distinct, well-separated, and compact clusters. This makes it a strong candidate for segmenting audiences and identifying influential users within a social media network.
#
# **Agglomerative Clustering:**
# ------------------------------------------
#
#   **Davies-Bouldin Index:** 0.806
#
#   **Silhouette Score**: 0.314
#
#   **Calinski-Harabasz Index:** 1377.878
#
#   **Combined Interpretation**: Agglomerative Clustering also shows good performance, with slightly better compactness and separation as per the DBI and good cluster definition as indicated by the CH Index. It is suitable for tasks requiring well-defined clusters.
#
# **DBSCAN:**
# -----------------------------------------
#
#   **Davies-Bouldin Index:** 1.515
#
#   **Silhouette Score:** 0.057
#
#   **Calinski-Harabasz Index:** 150.503
#
#   **Combined Interpretation:** DBSCAN does not perform well on this dataset. The low Silhouette Score and Calinski-Harabasz Index, along with the high DBI, suggest that DBSCAN struggles to form well-defined clusters in this context.

# %% [markdown]
# ### STEP-8: Refinement and Iteration

# %% [markdown]
# ## SINCE THERE IS SCOPE OF IMPROVEMENT, WILL DO HYPER PARAMATER TUNNING :

# %% [markdown]
# ## USING GRIDSEARCH CV FOR K-Means

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, make_scorer

# Define parameter grid for K-Means
param_grid_kmeans = {
    'n_clusters': [2, 3, 4, 5, 6, 7, 8, 9, 10],
    'init': ['k-means++', 'random'],
    'max_iter': [300, 600, 900]
}

# Silhouette score as scoring method
scorer = make_scorer(silhouette_score)

# Grid search
grid_kmeans = GridSearchCV(KMeans(), param_grid_kmeans, scoring=scorer)
grid_kmeans.fit(scaled_features)

# Best parameters
print("Best parameters for K-Means:", grid_kmeans.best_params_)
# Out:
# Best parameters for K-Means: {'init': 'k-means++', 'max_iter': 300, 'n_clusters': 2}

# %% [markdown]
# ## USING Grid SEARCH FOR AGGLOMERATIVE CLUSTERING:

# %%
from sklearn.cluster import AgglomerativeClustering

# Define parameter grid for Agglomerative Clustering
param_grid_agglo = {
    'n_clusters': [2, 3, 4, 5, 6, 7, 8, 9, 10],
    'linkage': ['ward', 'complete', 'average', 'single']
}

# Custom scorer function for silhouette score
def agglo_scorer(estimator, X):
    cluster_labels = estimator.fit_predict(X)
    return silhouette_score(X, cluster_labels)

# Grid search
grid_agglo = GridSearchCV(AgglomerativeClustering(), param_grid_agglo, scoring=agglo_scorer)
grid_agglo.fit(scaled_features)

# Best parameters
print("Best parameters for Agglomerative Clustering:", grid_agglo.best_params_)
# Out:
# Best parameters for Agglomerative Clustering: {'linkage': 'complete', 'n_clusters': 2}

# %% [markdown]
# ### USING GRIDSEARCH FOR DBSCAN

# %%
from sklearn.cluster import DBSCAN

# Define parameter grid for DBSCAN
param_grid_dbscan = {
    'eps': [0.1, 0.3, 0.5, 0.7, 0.9],
    'min_samples': [5, 10, 20, 30, 40]
}

# Custom scorer function for silhouette score
def dbscan_scorer(estimator, X):
    cluster_labels = estimator.fit_predict(X)
    # DBSCAN can label some points as -1 (noise), ignore these points for silhouette score
    if len(set(cluster_labels)) > 1:
        return silhouette_score(X, cluster_labels)
    else:
        return -1  # or any other invalid score when there's only one cluster

# Grid search
grid_dbscan = GridSearchCV(DBSCAN(), param_grid_dbscan, scoring=dbscan_scorer)
grid_dbscan.fit(scaled_features)

# Best parameters
print("Best parameters for DBSCAN:", grid_dbscan.best_params_)
# Out:
# Best parameters for DBSCAN: {'eps': 0.9, 'min_samples': 5}

# %% [markdown]
# ### Using optuna for Hyperparameter Optimization

# %%
# Define objective function for K-Means
def objective_kmeans(trial):
    n_clusters = trial.suggest_int('n_clusters', 2, 10)
    init = trial.suggest_categorical('init', ['k-means++', 'random'])
    max_iter = trial.suggest_int('max_iter', 100, 1000)

    kmeans = KMeans(n_clusters=n_clusters, init=init, max_iter=max_iter)
    kmeans.fit(scaled_features)
    score = silhouette_score(scaled_features, kmeans.labels_)
    return score

# Function to optimize Agglomerative Clustering
def objective_agglo(trial):
    n_clusters = trial.suggest_int('n_clusters', 2, 10)
    linkage = trial.suggest_categorical('linkage', ['ward', 'complete', 'average', 'single'])

    agglo = AgglomerativeClustering(n_clusters=n_clusters, linkage=linkage)
    labels = agglo.fit_predict(scaled_features)
    score = silhouette_score(scaled_features, labels)
    return score

# Function to optimize DBSCAN
def objective_dbscan(trial):
    eps = trial.suggest_uniform('eps', 0.1, 1.0)
    min_samples = trial.suggest_int('min_samples', 5, 50)

    dbscan = DBSCAN(eps=eps, min_samples=min_samples)
    labels = dbscan.fit_predict(scaled_features)
    # Handle case with only one cluster
    if len(set(labels)) > 1:
        score = silhouette_score(scaled_features, labels)
    else:
        score = -1
    return score

# Optimize K-Means
study_kmeans = optuna.create_study(direction='maximize')
study_kmeans.optimize(objective_kmeans, n_trials=50)
print("Best parameters for K-Means:", study_kmeans.best_params)

# Optimize Agglomerative Clustering
study_agglo = optuna.create_study(direction='maximize')
study_agglo.optimize(objective_agglo, n_trials=50)
print("Best parameters for Agglomerative Clustering:", study_agglo.best_params)

# Optimize DBSCAN
study_dbscan = optuna.create_study(direction='maximize')
study_dbscan.optimize(objective_dbscan, n_trials=50)
print("Best parameters for DBSCAN:", study_dbscan.best_params)
# Out:
# [I 2024-05-29 19:04:22,856] A new study created in memory with name: no-name-05ce9539-951b-42d6-afdc-27d14f77fdf5
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:24,950] Trial 0 finished with value: 0.2729455699731926 and parameters: {'n_clusters': 6, 'init': 'random', 'max_iter': 897}. Best is trial 0 with value: 0.2729455699731926.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:25,739] Trial 1 finished with value: 0.3152823704440016 and parameters: {'n_clusters': 2, 'init': 'random', 'max_iter': 845}. Best is trial 1 with value: 0.3152823704440016.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:26,883] Trial 2 finished with value: 0.2947383244708394 and parameters: {'n_clusters': 8, 'init': 'k-means++', 'max_iter': 438}. Best is trial 1 with value: 0.3152823704440016.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:27,196] Trial 3 finished with value: 0.27878272820024164 and parameters: {'n_clusters': 3, 'init': 'random', 'max_iter': 891}. Best is trial 1 with value: 0.3152823704440016.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:27,524] Trial 4 finished with value: 0.2875428469761587 and parameters: {'n_clusters': 9, 'init': 'random', 'max_iter': 493}. Best is trial 1 with value: 0.3152823704440016.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:27,853] Trial 5 finished with value: 0.3115898115749642 and parameters: {'n_clusters': 8, 'init': 'random', 'max_iter': 130}. Best is trial 1 with value: 0.3152823704440016.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:28,192] Trial 6 finished with value: 0.27878272820024164 and parameters: {'n_clusters': 3, 'init': 'random', 'max_iter': 289}. Best is trial 1 with value: 0.3152823704440016.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:28,532] Trial 7 finished with value: 0.31877285678023554 and parameters: {'n_clusters': 9, 'init': 'random', 'max_iter': 304}. Best is trial 7 with value: 0.31877285678023554.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:28,878] Trial 8 finished with value: 0.3354400192329136 and parameters: {'n_clusters': 10, 'init': 'random', 'max_iter': 439}. Best is trial 8 with value: 0.3354400192329136.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:29,247] Trial 9 finished with value: 0.33367495033059374 and parameters: {'n_clusters': 10, 'init': 'random', 'max_iter': 428}. Best is trial 8 with value: 0.3354400192329136.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:30,341] Trial 10 finished with value: 0.286961456138895 and parameters: {'n_clusters': 6, 'init': 'k-means++', 'max_iter': 694}. Best is trial 8 with value: 0.3354400192329136.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:31,265] Trial 11 finished with value: 0.3335040367160084 and parameters: {'n_clusters': 10, 'init': 'k-means++', 'max_iter': 628}. Best is trial 8 with value: 0.3354400192329136.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:31,601] Trial 12 finished with value: 0.33773900602782336 and parameters: {'n_clusters': 10, 'init': 'random', 'max_iter': 362}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:33,605] Trial 13 finished with value: 0.3035169944996599 and parameters: {'n_clusters': 7, 'init': 'random', 'max_iter': 280}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:35,429] Trial 14 finished with value: 0.2715083678884452 and parameters: {'n_clusters': 5, 'init': 'k-means++', 'max_iter': 614}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:35,780] Trial 15 finished with value: 0.33716908136430807 and parameters: {'n_clusters': 10, 'init': 'random', 'max_iter': 112}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:36,129] Trial 16 finished with value: 0.2942594693250725 and parameters: {'n_clusters': 8, 'init': 'random', 'max_iter': 146}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:36,496] Trial 17 finished with value: 0.32143197942422846 and parameters: {'n_clusters': 9, 'init': 'random', 'max_iter': 210}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:37,577] Trial 18 finished with value: 0.27121004779279867 and parameters: {'n_clusters': 5, 'init': 'k-means++', 'max_iter': 342}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:37,922] Trial 19 finished with value: 0.30335841204685876 and parameters: {'n_clusters': 7, 'init': 'random', 'max_iter': 107}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:38,272] Trial 20 finished with value: 0.3335040367160084 and parameters: {'n_clusters': 10, 'init': 'random', 'max_iter': 222}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:38,618] Trial 21 finished with value: 0.3136155855206393 and parameters: {'n_clusters': 10, 'init': 'random', 'max_iter': 447}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:38,961] Trial 22 finished with value: 0.32096438979346864 and parameters: {'n_clusters': 9, 'init': 'random', 'max_iter': 363}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:39,334] Trial 23 finished with value: 0.3359911312806889 and parameters: {'n_clusters': 10, 'init': 'random', 'max_iter': 549}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:39,697] Trial 24 finished with value: 0.320854116653843 and parameters: {'n_clusters': 9, 'init': 'random', 'max_iter': 792}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:40,046] Trial 25 finished with value: 0.2866943333505205 and parameters: {'n_clusters': 8, 'init': 'random', 'max_iter': 539}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:40,958] Trial 26 finished with value: 0.3032276124154944 and parameters: {'n_clusters': 7, 'init': 'k-means++', 'max_iter': 724}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:41,334] Trial 27 finished with value: 0.3354291942261474 and parameters: {'n_clusters': 10, 'init': 'random', 'max_iter': 553}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:41,687] Trial 28 finished with value: 0.31877522214258414 and parameters: {'n_clusters': 9, 'init': 'random', 'max_iter': 214}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:42,029] Trial 29 finished with value: 0.2828453370534048 and parameters: {'n_clusters': 6, 'init': 'random', 'max_iter': 956}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:42,394] Trial 30 finished with value: 0.33773900602782336 and parameters: {'n_clusters': 10, 'init': 'random', 'max_iter': 624}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:42,766] Trial 31 finished with value: 0.33770922836892214 and parameters: {'n_clusters': 10, 'init': 'random', 'max_iter': 632}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:43,135] Trial 32 finished with value: 0.3188905020289016 and parameters: {'n_clusters': 9, 'init': 'random', 'max_iter': 651}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:43,486] Trial 33 finished with value: 0.33365218547662295 and parameters: {'n_clusters': 10, 'init': 'random', 'max_iter': 784}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:43,837] Trial 34 finished with value: 0.2940747120758412 and parameters: {'n_clusters': 8, 'init': 'random', 'max_iter': 725}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:44,188] Trial 35 finished with value: 0.29927721470571556 and parameters: {'n_clusters': 9, 'init': 'random', 'max_iter': 668}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:44,531] Trial 36 finished with value: 0.3152823704440016 and parameters: {'n_clusters': 2, 'init': 'random', 'max_iter': 575}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:46,050] Trial 37 finished with value: 0.3142455088279891 and parameters: {'n_clusters': 10, 'init': 'k-means++', 'max_iter': 376}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:47,945] Trial 38 finished with value: 0.287440247389486 and parameters: {'n_clusters': 5, 'init': 'random', 'max_iter': 515}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:49,327] Trial 39 finished with value: 0.2652595073853545 and parameters: {'n_clusters': 4, 'init': 'random', 'max_iter': 472}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:49,678] Trial 40 finished with value: 0.3130288486426083 and parameters: {'n_clusters': 8, 'init': 'random', 'max_iter': 161}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:50,052] Trial 41 finished with value: 0.3359911312806889 and parameters: {'n_clusters': 10, 'init': 'random', 'max_iter': 595}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:50,422] Trial 42 finished with value: 0.3361633443965839 and parameters: {'n_clusters': 10, 'init': 'random', 'max_iter': 793}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:50,804] Trial 43 finished with value: 0.317360475463725 and parameters: {'n_clusters': 9, 'init': 'random', 'max_iter': 825}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:51,160] Trial 44 finished with value: 0.3152799023629596 and parameters: {'n_clusters': 10, 'init': 'random', 'max_iter': 900}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:51,512] Trial 45 finished with value: 0.2873432453324025 and parameters: {'n_clusters': 9, 'init': 'random', 'max_iter': 707}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:51,882] Trial 46 finished with value: 0.3030888553568369 and parameters: {'n_clusters': 10, 'init': 'random', 'max_iter': 876}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:52,989] Trial 47 finished with value: 0.31877285678023554 and parameters: {'n_clusters': 9, 'init': 'k-means++', 'max_iter': 774}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:53,352] Trial 48 finished with value: 0.33557482344304834 and parameters: {'n_clusters': 10, 'init': 'random', 'max_iter': 414}. Best is trial 12 with value: 0.33773900602782336.
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [I 2024-05-29 19:04:53,703] Trial 49 finished with value: 0.28823007709496695 and parameters: {'n_clusters': 8, 'init': 'random', 'max_iter': 266}. Best is trial 12 with value: 0.33773900602782336.
# [I 2024-05-29 19:04:53,707] A new study created in memory with name: no-name-ca93a292-7536-4e10-a393-60310fafdd13
# Best parameters for K-Means: {'n_clusters': 10, 'init': 'random', 'max_iter': 362}
# [I 2024-05-29 19:04:54,536] Trial 0 finished with value: 0.2984546361713334 and parameters: {'n_clusters': 9, 'linkage': 'ward'}. Best is trial 0 with value: 0.2984546361713334.
# [I 2024-05-29 19:04:55,291] Trial 1 finished with value: 0.5473668412138567 and parameters: {'n_clusters': 9, 'linkage': 'complete'}. Best is trial 1 with value: 0.5473668412138567.
# [I 2024-05-29 19:04:56,096] Trial 2 finished with value: 0.5673236172814539 and parameters: {'n_clusters': 10, 'linkage': 'average'}. Best is trial 2 with value: 0.5673236172814539.
# [I 2024-05-29 19:04:56,879] Trial 3 finished with value: 0.5673236172814539 and parameters: {'n_clusters': 10, 'linkage': 'average'}. Best is trial 2 with value: 0.5673236172814539.
# [I 2024-05-29 19:04:57,661] Trial 4 finished with value: 0.3161399031512658 and parameters: {'n_clusters': 10, 'linkage': 'ward'}. Best is trial 2 with value: 0.5673236172814539.
# [I 2024-05-29 19:04:58,452] Trial 5 finished with value: 0.3161399031512658 and parameters: {'n_clusters': 10, 'linkage': 'ward'}. Best is trial 2 with value: 0.5673236172814539.
# [I 2024-05-29 19:04:59,300] Trial 6 finished with value: 0.2984546361713334 and parameters: {'n_clusters': 9, 'linkage': 'ward'}. Best is trial 2 with value: 0.5673236172814539.
# [I 2024-05-29 19:05:00,427] Trial 7 finished with value: 0.6751947690821077 and parameters: {'n_clusters': 6, 'linkage': 'complete'}. Best is trial 7 with value: 0.6751947690821077.
# [I 2024-05-29 19:05:01,101] Trial 8 finished with value: 0.5684246363904706 and parameters: {'n_clusters': 10, 'linkage': 'single'}. Best is trial 7 with value: 0.6751947690821077.
# [I 2024-05-29 19:05:01,817] Trial 9 finished with value: 0.5689673443618928 and parameters: {'n_clusters': 8, 'linkage': 'single'}. Best is trial 7 with value: 0.6751947690821077.
# [I 2024-05-29 19:05:03,096] Trial 10 finished with value: 0.9038342367176712 and parameters: {'n_clusters': 3, 'linkage': 'complete'}. Best is trial 10 with value: 0.9038342367176712.
# [I 2024-05-29 19:05:04,301] Trial 11 finished with value: 0.9038342367176712 and parameters: {'n_clusters': 3, 'linkage': 'complete'}. Best is trial 10 with value: 0.9038342367176712.
# [I 2024-05-29 19:05:05,490] Trial 12 finished with value: 0.9142392878111313 and parameters: {'n_clusters': 2, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:06,664] Trial 13 finished with value: 0.9142392878111313 and parameters: {'n_clusters': 2, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:07,450] Trial 14 finished with value: 0.9142392878111313 and parameters: {'n_clusters': 2, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:08,188] Trial 15 finished with value: 0.6752715208020653 and parameters: {'n_clusters': 5, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:08,933] Trial 16 finished with value: 0.9003198856235682 and parameters: {'n_clusters': 4, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:09,673] Trial 17 finished with value: 0.9142392878111313 and parameters: {'n_clusters': 2, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:10,463] Trial 18 finished with value: 0.8864489815209156 and parameters: {'n_clusters': 5, 'linkage': 'average'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:10,900] Trial 19 finished with value: 0.9038342367176712 and parameters: {'n_clusters': 3, 'linkage': 'single'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:11,659] Trial 20 finished with value: 0.6530394379238628 and parameters: {'n_clusters': 7, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:12,390] Trial 21 finished with value: 0.9142392878111313 and parameters: {'n_clusters': 2, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:13,141] Trial 22 finished with value: 0.9142392878111313 and parameters: {'n_clusters': 2, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:13,889] Trial 23 finished with value: 0.9003198856235682 and parameters: {'n_clusters': 4, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:14,624] Trial 24 finished with value: 0.9142392878111313 and parameters: {'n_clusters': 2, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:15,356] Trial 25 finished with value: 0.9003198856235682 and parameters: {'n_clusters': 4, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:16,296] Trial 26 finished with value: 0.9038342367176712 and parameters: {'n_clusters': 3, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:16,939] Trial 27 finished with value: 0.9142392878111313 and parameters: {'n_clusters': 2, 'linkage': 'single'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:18,118] Trial 28 finished with value: 0.8864489815209156 and parameters: {'n_clusters': 5, 'linkage': 'average'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:19,379] Trial 29 finished with value: 0.31445549654828303 and parameters: {'n_clusters': 3, 'linkage': 'ward'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:20,335] Trial 30 finished with value: 0.9003198856235682 and parameters: {'n_clusters': 4, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:21,076] Trial 31 finished with value: 0.9142392878111313 and parameters: {'n_clusters': 2, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:21,805] Trial 32 finished with value: 0.9142392878111313 and parameters: {'n_clusters': 2, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:22,577] Trial 33 finished with value: 0.9038342367176712 and parameters: {'n_clusters': 3, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:23,320] Trial 34 finished with value: 0.9142392878111313 and parameters: {'n_clusters': 2, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:24,112] Trial 35 finished with value: 0.9038342367176712 and parameters: {'n_clusters': 3, 'linkage': 'average'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:24,846] Trial 36 finished with value: 0.9142392878111313 and parameters: {'n_clusters': 2, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:25,655] Trial 37 finished with value: 0.24995776961904714 and parameters: {'n_clusters': 4, 'linkage': 'ward'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:26,409] Trial 38 finished with value: 0.6751947690821077 and parameters: {'n_clusters': 6, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:27,208] Trial 39 finished with value: 0.9038342367176712 and parameters: {'n_clusters': 3, 'linkage': 'average'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:28,002] Trial 40 finished with value: 0.30418818668114456 and parameters: {'n_clusters': 2, 'linkage': 'ward'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:28,730] Trial 41 finished with value: 0.9142392878111313 and parameters: {'n_clusters': 2, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:29,468] Trial 42 finished with value: 0.9142392878111313 and parameters: {'n_clusters': 2, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:30,274] Trial 43 finished with value: 0.9038342367176712 and parameters: {'n_clusters': 3, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:31,382] Trial 44 finished with value: 0.9142392878111313 and parameters: {'n_clusters': 2, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:31,994] Trial 45 finished with value: 0.9038342367176712 and parameters: {'n_clusters': 3, 'linkage': 'single'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:33,137] Trial 46 finished with value: 0.9142392878111313 and parameters: {'n_clusters': 2, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:34,265] Trial 47 finished with value: 0.5474551448633033 and parameters: {'n_clusters': 8, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:35,039] Trial 48 finished with value: 0.9038342367176712 and parameters: {'n_clusters': 3, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:35,784] Trial 49 finished with value: 0.9003198856235682 and parameters: {'n_clusters': 4, 'linkage': 'complete'}. Best is trial 12 with value: 0.9142392878111313.
# [I 2024-05-29 19:05:35,786] A new study created in memory with name: no-name-ee83278a-7b2d-4010-881e-836b20429f86
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:35,914] Trial 0 finished with value: -1.0 and parameters: {'eps': 0.17766556221103752, 'min_samples': 44}. Best is trial 0 with value: -1.0.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# Best parameters for Agglomerative Clustering: {'n_clusters': 2, 'linkage': 'complete'}
# [I 2024-05-29 19:05:36,427] Trial 1 finished with value: 0.18464660686414944 and parameters: {'eps': 0.7424446285380972, 'min_samples': 31}. Best is trial 1 with value: 0.18464660686414944.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:36,858] Trial 2 finished with value: -0.13010228701679252 and parameters: {'eps': 0.34510870334577676, 'min_samples': 30}. Best is trial 1 with value: 0.18464660686414944.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:37,294] Trial 3 finished with value: 0.014027743248415176 and parameters: {'eps': 0.3794783890022999, 'min_samples': 25}. Best is trial 1 with value: 0.18464660686414944.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:37,786] Trial 4 finished with value: 0.13058574430342215 and parameters: {'eps': 0.6041686724614397, 'min_samples': 5}. Best is trial 1 with value: 0.18464660686414944.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:38,301] Trial 5 finished with value: 0.16129383731340347 and parameters: {'eps': 0.7391501883652553, 'min_samples': 26}. Best is trial 1 with value: 0.18464660686414944.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:38,719] Trial 6 finished with value: 0.18122577918654653 and parameters: {'eps': 0.2031550649466537, 'min_samples': 38}. Best is trial 1 with value: 0.18464660686414944.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:39,167] Trial 7 finished with value: 0.155418804667502 and parameters: {'eps': 0.4487932735469077, 'min_samples': 17}. Best is trial 1 with value: 0.18464660686414944.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:39,274] Trial 8 finished with value: -1.0 and parameters: {'eps': 0.13050127302410072, 'min_samples': 39}. Best is trial 1 with value: 0.18464660686414944.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:39,722] Trial 9 finished with value: -0.10160743019044445 and parameters: {'eps': 0.38172598107351163, 'min_samples': 44}. Best is trial 1 with value: 0.18464660686414944.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:40,337] Trial 10 finished with value: 0.238626679222259 and parameters: {'eps': 0.9815485749937003, 'min_samples': 15}. Best is trial 10 with value: 0.238626679222259.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:40,946] Trial 11 finished with value: 0.24359449223636884 and parameters: {'eps': 0.9918359650659094, 'min_samples': 13}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:41,566] Trial 12 finished with value: 0.22180336420034655 and parameters: {'eps': 0.9920385517274974, 'min_samples': 10}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:42,174] Trial 13 finished with value: 0.24010152101617793 and parameters: {'eps': 0.9951207577911657, 'min_samples': 16}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:42,744] Trial 14 finished with value: 0.19672206692807026 and parameters: {'eps': 0.8624997933356175, 'min_samples': 19}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:43,302] Trial 15 finished with value: 0.20360310445407823 and parameters: {'eps': 0.8533616896201065, 'min_samples': 10}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:43,881] Trial 16 finished with value: 0.19692025220152107 and parameters: {'eps': 0.883393088131891, 'min_samples': 21}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:44,402] Trial 17 finished with value: 0.11958464475193824 and parameters: {'eps': 0.6575153918189842, 'min_samples': 10}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:45,186] Trial 18 finished with value: 0.18110453951722794 and parameters: {'eps': 0.7710065950291995, 'min_samples': 14}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:46,009] Trial 19 finished with value: 0.13770642939396446 and parameters: {'eps': 0.9227217215999088, 'min_samples': 6}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:46,638] Trial 20 finished with value: 0.16861739909839576 and parameters: {'eps': 0.512945557219792, 'min_samples': 24}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:47,510] Trial 21 finished with value: 0.23863827885163966 and parameters: {'eps': 0.994872247524415, 'min_samples': 15}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:49,481] Trial 22 finished with value: 0.23924299368345467 and parameters: {'eps': 0.9442644378128829, 'min_samples': 14}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:50,032] Trial 23 finished with value: 0.17915539705264474 and parameters: {'eps': 0.8110957657875459, 'min_samples': 21}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:50,606] Trial 24 finished with value: 0.15971639845124888 and parameters: {'eps': 0.9082325306908546, 'min_samples': 12}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:51,129] Trial 25 finished with value: 0.15612067530656534 and parameters: {'eps': 0.6757710308723598, 'min_samples': 7}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:51,705] Trial 26 finished with value: 0.23785569133337708 and parameters: {'eps': 0.9349927649021346, 'min_samples': 20}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:52,261] Trial 27 finished with value: 0.1830197084274775 and parameters: {'eps': 0.8100152335073869, 'min_samples': 17}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:52,840] Trial 28 finished with value: 0.23515735492438133 and parameters: {'eps': 0.9424621970294988, 'min_samples': 31}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:53,402] Trial 29 finished with value: 0.1951928622419627 and parameters: {'eps': 0.8228452900279186, 'min_samples': 8}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:53,910] Trial 30 finished with value: 0.10850171785525657 and parameters: {'eps': 0.6682163907487106, 'min_samples': 12}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:54,518] Trial 31 finished with value: 0.23863827885163966 and parameters: {'eps': 0.994957050814556, 'min_samples': 15}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:55,096] Trial 32 finished with value: 0.23954164414720794 and parameters: {'eps': 0.9506970040349781, 'min_samples': 17}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:55,679] Trial 33 finished with value: 0.1685107969661753 and parameters: {'eps': 0.9253879373985001, 'min_samples': 22}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:56,216] Trial 34 finished with value: 0.19006614560204735 and parameters: {'eps': 0.7489464213042742, 'min_samples': 29}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:56,769] Trial 35 finished with value: 0.21048198238405993 and parameters: {'eps': 0.8733569952245498, 'min_samples': 50}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:57,371] Trial 36 finished with value: 0.23417156149104706 and parameters: {'eps': 0.9483728402325171, 'min_samples': 34}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:57,788] Trial 37 finished with value: -0.361419240718775 and parameters: {'eps': 0.22905678987941275, 'min_samples': 18}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:58,356] Trial 38 finished with value: 0.20170682420578945 and parameters: {'eps': 0.8375217713294376, 'min_samples': 13}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:58,943] Trial 39 finished with value: 0.17199526971282242 and parameters: {'eps': 0.7790140544170302, 'min_samples': 25}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:05:59,411] Trial 40 finished with value: -0.14111909483502025 and parameters: {'eps': 0.2817382081786714, 'min_samples': 17}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:06:00,280] Trial 41 finished with value: 0.23999982807252135 and parameters: {'eps': 0.9974676417026496, 'min_samples': 16}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:06:01,133] Trial 42 finished with value: 0.22180336420034655 and parameters: {'eps': 0.9641424605707105, 'min_samples': 10}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:06:01,953] Trial 43 finished with value: 0.21821970117738068 and parameters: {'eps': 0.8979975518158964, 'min_samples': 23}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:06:02,843] Trial 44 finished with value: 0.23999982807252135 and parameters: {'eps': 0.9998759069247509, 'min_samples': 16}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:06:03,715] Trial 45 finished with value: 0.23921098269153315 and parameters: {'eps': 0.9620548393411429, 'min_samples': 19}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:06:04,370] Trial 46 finished with value: 0.23999982807252135 and parameters: {'eps': 0.9993215303867155, 'min_samples': 16}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:06:04,970] Trial 47 finished with value: 0.2378018642743787 and parameters: {'eps': 0.9944410736442835, 'min_samples': 27}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:06:05,543] Trial 48 finished with value: 0.18722065690257522 and parameters: {'eps': 0.887319811396786, 'min_samples': 8}. Best is trial 11 with value: 0.24359449223636884.
# <ipython-input-12-d611c2892319>:24: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   eps = trial.suggest_uniform('eps', 0.1, 1.0)
# [I 2024-05-29 19:06:06,067] Trial 49 finished with value: 0.17442612719706574 and parameters: {'eps': 0.7168797659623056, 'min_samples': 5}. Best is trial 11 with value: 0.24359449223636884.
# Best parameters for DBSCAN: {'eps': 0.9918359650659094, 'min_samples': 13}

# %%
print("Best parameters for K-Means:", study_kmeans.best_params)
print("Best parameters for Agglomerative Clustering:", study_agglo.best_params)
print("Best parameters for DBSCAN:", study_dbscan.best_params)
# Out:
# Best parameters for K-Means: {'n_clusters': 10, 'init': 'random', 'max_iter': 362}
# Best parameters for Agglomerative Clustering: {'n_clusters': 2, 'linkage': 'complete'}
# Best parameters for DBSCAN: {'eps': 0.9918359650659094, 'min_samples': 13}

# %% [markdown]
# ## APPLYING BEST PARAMATERS(Trial-1) FOR EVALUATION:

# %%
# Apply Best Parameters for K-Means
best_kmeans = KMeans(n_clusters= 10, init= 'random' , max_iter=362, random_state=42)
best_kmeans.fit(scaled_features)
cluster_labels_best_kmeans = best_kmeans.labels_

# Evaluate Silhouette Score for K-Means with Best Parameters
silhouette_score_best_kmeans = silhouette_score(scaled_features, cluster_labels_best_kmeans)
# Out:
# Silhouette Score (K-Means with Best Parameters): 0.336

# %%
# Apply Best Parameters for Agglomerative Clustering
best_agglo = AgglomerativeClustering(n_clusters=2, linkage='complete')
best_agglo.fit(scaled_features)
cluster_labels_best_agglo = best_agglo.labels_

# Evaluate Silhouette Score for Agglomerative Clustering with Best Parameters
silhouette_score_best_agglo = silhouette_score(scaled_features, cluster_labels_best_agglo)
# Out:
# Silhouette Score (Agglomerative Clustering with Best Parameters): 0.914

# %%
# Apply Best Parameters for DBSCAN
best_dbscan = DBSCAN(eps=0.9918359650659094, min_samples=13)
best_dbscan.fit(scaled_features)
cluster_labels_best_dbscan = best_dbscan.labels_

# Evaluate Silhouette Score for DBSCAN with Best Parameters
silhouette_score_best_dbscan = silhouette_score(scaled_features, cluster_labels_best_dbscan)
# Out:
# Silhouette Score (DBSCAN with Best Parameters): 0.244

# %%
print("Silhouette Score (K-Means with Best Parameters):", silhouette_score_best_kmeans.round(3))
print("Silhouette Score (Agg_Clustering with Best Parameters):", silhouette_score_best_agglo.round(3))
print("Silhouette Score (DBSCAN with Best Parameters):", silhouette_score_best_dbscan.round(3))
# Out:
# Silhouette Score (K-Means with Best Parameters): 0.336
# Silhouette Score (Agg_Clustering with Best Parameters): 0.914
# Silhouette Score (DBSCAN with Best Parameters): 0.244

# %% [markdown]
# ###  FINDING HYPER PARAMETER (Trial-2) FOR EVALUATION:

# %%
# Example synthetic data for demonstration and then apply with y actual data
from sklearn.datasets import make_blobs
features, _ = make_blobs(n_samples=1000, centers=5, n_features=8, random_state=42)
features = pd.DataFrame(features, columns=['degree', 'clustering', 'betweenness', 'closeness', 'avg_neighbor_degree', 'pagerank', '2hop_degree', '3hop_degree'])

# Scale features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

"""
After generating the synthetic data using make_blobs, the data is stored in the features DataFrame,
which has the same column structure as my actual data. Then, the StandardScaler is applied to scale the features.
So, after the make_blobs step, i am  preparing this synthetic data to be fed into my analysis pipeline, mimicking the steps i would take with my actual data.

"""
# Define objective function for K-Means
def objective_kmeans(trial):
    n_clusters = trial.suggest_int('n_clusters', 2, 10)
    init = trial.suggest_categorical('init', ['k-means++', 'random'])
    max_iter = trial.suggest_int('max_iter', 100, 1000)

    kmeans = KMeans(n_clusters=n_clusters, init=init, max_iter=max_iter)
    kmeans.fit(scaled_features)
    score = silhouette_score(scaled_features, kmeans.labels_)
    return score

# Define objective function for Agglomerative Clustering
def objective_agg(trial):
    n_clusters = trial.suggest_int('n_clusters', 2, 10)

    hierarchical = AgglomerativeClustering(n_clusters=n_clusters)
    hierarchical.fit(scaled_features)
    score = silhouette_score(scaled_features, hierarchical.labels_)
    return score

# Define objective function for DBSCAN
def objective_dbscan(trial):
    eps = trial.suggest_float('eps', 0.1, 2.0)
    min_samples = trial.suggest_int('min_samples', 2, 10)

    dbscan = DBSCAN(eps=eps, min_samples=min_samples)
    dbscan.fit(scaled_features)

    # Check if DBSCAN identified any clusters, as silhouette score requires more than one cluster
    if len(set(dbscan.labels_)) > 1:
        score = silhouette_score(scaled_features, dbscan.labels_)
    else:
        score = -1  # Assign a low score if only one cluster is found
    return score

# Optimize K-Means
study_kmeans = optuna.create_study(direction='maximize')
study_kmeans.optimize(objective_kmeans, n_trials=50)
#print("Best parameters for K-Means:", study_kmeans.best_trial.params)

# Optimize Agglomerative Clustering
study_agg = optuna.create_study(direction='maximize')
study_agg.optimize(objective_agg, n_trials=50)
#print("Best parameters for Agglomerative Clustering:", study_agg.best_trial.params)

# Optimize DBSCAN
study_dbscan = optuna.create_study(direction='maximize')
study_dbscan.optimize(objective_dbscan, n_trials=50)
#print("Best parameters for DBSCAN:", study_dbscan.best_trial.params)
# Out:
# [I 2024-05-29 20:46:29,100] A new study created in memory with name: no-name-3c1917ec-f8b1-4219-8d1f-755f4744491d
# [I 2024-05-29 20:46:30,471] Trial 0 finished with value: 0.5837924621113171 and parameters: {'n_clusters': 6, 'init': 'k-means++', 'max_iter': 265}. Best is trial 0 with value: 0.5837924621113171.
# [I 2024-05-29 20:46:31,909] Trial 1 finished with value: 0.35075172602818583 and parameters: {'n_clusters': 10, 'init': 'random', 'max_iter': 135}. Best is trial 0 with value: 0.5837924621113171.
# [I 2024-05-29 20:46:32,752] Trial 2 finished with value: 0.5879596786075999 and parameters: {'n_clusters': 6, 'init': 'random', 'max_iter': 965}. Best is trial 2 with value: 0.5879596786075999.
# [I 2024-05-29 20:46:33,773] Trial 3 finished with value: 0.4241563299121481 and parameters: {'n_clusters': 2, 'init': 'k-means++', 'max_iter': 112}. Best is trial 2 with value: 0.5879596786075999.
# [I 2024-05-29 20:46:33,905] Trial 4 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5, 'init': 'k-means++', 'max_iter': 312}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:34,028] Trial 5 finished with value: 0.4241563299121481 and parameters: {'n_clusters': 2, 'init': 'k-means++', 'max_iter': 487}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:34,899] Trial 6 finished with value: 0.5841146617102205 and parameters: {'n_clusters': 6, 'init': 'k-means++', 'max_iter': 694}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:35,098] Trial 7 finished with value: 0.5837924621113171 and parameters: {'n_clusters': 6, 'init': 'random', 'max_iter': 656}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:35,845] Trial 8 finished with value: 0.49335828624002037 and parameters: {'n_clusters': 3, 'init': 'random', 'max_iter': 373}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:36,011] Trial 9 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5, 'init': 'random', 'max_iter': 841}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:36,155] Trial 10 finished with value: 0.36192559644726224 and parameters: {'n_clusters': 9, 'init': 'k-means++', 'max_iter': 390}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:36,282] Trial 11 finished with value: 0.6012598453208343 and parameters: {'n_clusters': 4, 'init': 'random', 'max_iter': 935}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:36,411] Trial 12 finished with value: 0.6012598453208343 and parameters: {'n_clusters': 4, 'init': 'random', 'max_iter': 790}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:36,559] Trial 13 finished with value: 0.4466545176118412 and parameters: {'n_clusters': 8, 'init': 'k-means++', 'max_iter': 563}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:36,700] Trial 14 finished with value: 0.6012598453208343 and parameters: {'n_clusters': 4, 'init': 'k-means++', 'max_iter': 828}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:36,832] Trial 15 finished with value: 0.5076798564530332 and parameters: {'n_clusters': 7, 'init': 'random', 'max_iter': 268}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:36,898] Trial 16 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5, 'init': 'k-means++', 'max_iter': 533}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:37,031] Trial 17 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5, 'init': 'random', 'max_iter': 829}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:37,097] Trial 18 finished with value: 0.4472626501565112 and parameters: {'n_clusters': 8, 'init': 'random', 'max_iter': 655}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:37,234] Trial 19 finished with value: 0.49335828624002037 and parameters: {'n_clusters': 3, 'init': 'k-means++', 'max_iter': 238}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:37,368] Trial 20 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5, 'init': 'random', 'max_iter': 401}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:37,505] Trial 21 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5, 'init': 'k-means++', 'max_iter': 524}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:37,648] Trial 22 finished with value: 0.5085595635580813 and parameters: {'n_clusters': 7, 'init': 'k-means++', 'max_iter': 592}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:37,777] Trial 23 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5, 'init': 'k-means++', 'max_iter': 477}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:37,919] Trial 24 finished with value: 0.510261327249362 and parameters: {'n_clusters': 7, 'init': 'k-means++', 'max_iter': 719}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:38,049] Trial 25 finished with value: 0.49335828624002037 and parameters: {'n_clusters': 3, 'init': 'k-means++', 'max_iter': 911}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:38,119] Trial 26 finished with value: 0.6012598453208343 and parameters: {'n_clusters': 4, 'init': 'k-means++', 'max_iter': 319}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:38,239] Trial 27 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5, 'init': 'k-means++', 'max_iter': 443}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:38,366] Trial 28 finished with value: 0.6012598453208343 and parameters: {'n_clusters': 4, 'init': 'random', 'max_iter': 189}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:38,494] Trial 29 finished with value: 0.5837924621113171 and parameters: {'n_clusters': 6, 'init': 'k-means++', 'max_iter': 318}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:38,635] Trial 30 finished with value: 0.4981847483618057 and parameters: {'n_clusters': 7, 'init': 'k-means++', 'max_iter': 604}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:38,699] Trial 31 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5, 'init': 'random', 'max_iter': 837}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:38,760] Trial 32 finished with value: 0.5860728941814779 and parameters: {'n_clusters': 6, 'init': 'random', 'max_iter': 764}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:38,824] Trial 33 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5, 'init': 'random', 'max_iter': 877}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:38,892] Trial 34 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5, 'init': 'random', 'max_iter': 966}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:38,957] Trial 35 finished with value: 0.49335828624002037 and parameters: {'n_clusters': 3, 'init': 'random', 'max_iter': 741}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:39,022] Trial 36 finished with value: 0.5837924621113171 and parameters: {'n_clusters': 6, 'init': 'random', 'max_iter': 167}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:39,089] Trial 37 finished with value: 0.6012598453208343 and parameters: {'n_clusters': 4, 'init': 'random', 'max_iter': 672}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:39,200] Trial 38 finished with value: 0.2837115655997369 and parameters: {'n_clusters': 10, 'init': 'k-means++', 'max_iter': 835}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:39,267] Trial 39 finished with value: 0.5841146617102205 and parameters: {'n_clusters': 6, 'init': 'random', 'max_iter': 615}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:39,335] Trial 40 finished with value: 0.4241563299121481 and parameters: {'n_clusters': 2, 'init': 'k-means++', 'max_iter': 528}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:39,399] Trial 41 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5, 'init': 'random', 'max_iter': 417}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:39,465] Trial 42 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5, 'init': 'random', 'max_iter': 352}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:39,532] Trial 43 finished with value: 0.6012598453208343 and parameters: {'n_clusters': 4, 'init': 'random', 'max_iter': 477}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:39,619] Trial 44 finished with value: 0.5837924621113171 and parameters: {'n_clusters': 6, 'init': 'random', 'max_iter': 425}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:39,751] Trial 45 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5, 'init': 'random', 'max_iter': 263}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:39,820] Trial 46 finished with value: 0.6012598453208343 and parameters: {'n_clusters': 4, 'init': 'random', 'max_iter': 324}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:39,953] Trial 47 finished with value: 0.5854139195891123 and parameters: {'n_clusters': 6, 'init': 'random', 'max_iter': 379}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:40,083] Trial 48 finished with value: 0.49335828624002037 and parameters: {'n_clusters': 3, 'init': 'k-means++', 'max_iter': 787}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:40,215] Trial 49 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5, 'init': 'random', 'max_iter': 988}. Best is trial 4 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:40,223] A new study created in memory with name: no-name-57103d2c-ee6b-4315-9395-9b908cda7eb8
# [I 2024-05-29 20:46:40,281] Trial 0 finished with value: 0.49335828624002037 and parameters: {'n_clusters': 3}. Best is trial 0 with value: 0.49335828624002037.
# [I 2024-05-29 20:46:40,342] Trial 1 finished with value: 0.5827484877196331 and parameters: {'n_clusters': 6}. Best is trial 1 with value: 0.5827484877196331.
# [I 2024-05-29 20:46:40,398] Trial 2 finished with value: 0.5042200899253255 and parameters: {'n_clusters': 7}. Best is trial 1 with value: 0.5827484877196331.
# [I 2024-05-29 20:46:40,458] Trial 3 finished with value: 0.6012598453208343 and parameters: {'n_clusters': 4}. Best is trial 3 with value: 0.6012598453208343.
# [I 2024-05-29 20:46:40,513] Trial 4 finished with value: 0.2679087064081094 and parameters: {'n_clusters': 10}. Best is trial 3 with value: 0.6012598453208343.
# [I 2024-05-29 20:46:40,569] Trial 5 finished with value: 0.35344841127804333 and parameters: {'n_clusters': 9}. Best is trial 3 with value: 0.6012598453208343.
# [I 2024-05-29 20:46:40,649] Trial 6 finished with value: 0.49335828624002037 and parameters: {'n_clusters': 3}. Best is trial 3 with value: 0.6012598453208343.
# [I 2024-05-29 20:46:40,709] Trial 7 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:40,769] Trial 8 finished with value: 0.49335828624002037 and parameters: {'n_clusters': 3}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:40,828] Trial 9 finished with value: 0.4191222778629983 and parameters: {'n_clusters': 8}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:40,896] Trial 10 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:40,968] Trial 11 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:41,033] Trial 12 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:41,099] Trial 13 finished with value: 0.5827484877196331 and parameters: {'n_clusters': 6}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:41,166] Trial 14 finished with value: 0.4241563299121481 and parameters: {'n_clusters': 2}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:41,233] Trial 15 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:41,299] Trial 16 finished with value: 0.5042200899253255 and parameters: {'n_clusters': 7}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:41,371] Trial 17 finished with value: 0.5042200899253255 and parameters: {'n_clusters': 7}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:41,438] Trial 18 finished with value: 0.6012598453208343 and parameters: {'n_clusters': 4}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:41,506] Trial 19 finished with value: 0.5827484877196331 and parameters: {'n_clusters': 6}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:41,572] Trial 20 finished with value: 0.6012598453208343 and parameters: {'n_clusters': 4}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:41,647] Trial 21 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:41,727] Trial 22 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:41,795] Trial 23 finished with value: 0.6012598453208343 and parameters: {'n_clusters': 4}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:41,865] Trial 24 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:41,934] Trial 25 finished with value: 0.4241563299121481 and parameters: {'n_clusters': 2}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:41,997] Trial 26 finished with value: 0.4191222778629983 and parameters: {'n_clusters': 8}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:42,059] Trial 27 finished with value: 0.5827484877196331 and parameters: {'n_clusters': 6}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:42,126] Trial 28 finished with value: 0.6012598453208343 and parameters: {'n_clusters': 4}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:42,190] Trial 29 finished with value: 0.49335828624002037 and parameters: {'n_clusters': 3}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:42,258] Trial 30 finished with value: 0.5827484877196331 and parameters: {'n_clusters': 6}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:42,327] Trial 31 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:42,392] Trial 32 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:42,459] Trial 33 finished with value: 0.5042200899253255 and parameters: {'n_clusters': 7}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:42,532] Trial 34 finished with value: 0.6012598453208343 and parameters: {'n_clusters': 4}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:42,601] Trial 35 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:42,668] Trial 36 finished with value: 0.5827484877196331 and parameters: {'n_clusters': 6}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:42,764] Trial 37 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:42,832] Trial 38 finished with value: 0.49335828624002037 and parameters: {'n_clusters': 3}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:42,903] Trial 39 finished with value: 0.5827484877196331 and parameters: {'n_clusters': 6}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:42,975] Trial 40 finished with value: 0.5042200899253255 and parameters: {'n_clusters': 7}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:43,046] Trial 41 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:43,118] Trial 42 finished with value: 0.6012598453208343 and parameters: {'n_clusters': 4}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:43,187] Trial 43 finished with value: 0.6616895400878501 and parameters: {'n_clusters': 5}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:43,255] Trial 44 finished with value: 0.6012598453208343 and parameters: {'n_clusters': 4}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:43,323] Trial 45 finished with value: 0.5827484877196331 and parameters: {'n_clusters': 6}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:43,390] Trial 46 finished with value: 0.2679087064081094 and parameters: {'n_clusters': 10}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:43,458] Trial 47 finished with value: 0.5827484877196331 and parameters: {'n_clusters': 6}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:43,526] Trial 48 finished with value: 0.6012598453208343 and parameters: {'n_clusters': 4}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:43,595] Trial 49 finished with value: 0.49335828624002037 and parameters: {'n_clusters': 3}. Best is trial 7 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:43,600] A new study created in memory with name: no-name-f78d2e50-e805-4e64-a295-7a91cc46a842
# [I 2024-05-29 20:46:43,646] Trial 0 finished with value: 0.005396632697521969 and parameters: {'eps': 0.4935214810949301, 'min_samples': 6}. Best is trial 0 with value: 0.005396632697521969.
# [I 2024-05-29 20:46:43,705] Trial 1 finished with value: 0.6616895400878501 and parameters: {'eps': 1.4705204788249036, 'min_samples': 3}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:43,793] Trial 2 finished with value: 0.6616895400878501 and parameters: {'eps': 1.439281495448534, 'min_samples': 6}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:43,891] Trial 3 finished with value: 0.6439910589267025 and parameters: {'eps': 0.7445542396855042, 'min_samples': 6}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:43,982] Trial 4 finished with value: 0.6616895400878501 and parameters: {'eps': 1.0564686236879444, 'min_samples': 6}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:44,083] Trial 5 finished with value: -0.03406257623488797 and parameters: {'eps': 0.48488307847037415, 'min_samples': 4}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:44,191] Trial 6 finished with value: 0.6616895400878501 and parameters: {'eps': 1.2116551244855664, 'min_samples': 2}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:44,275] Trial 7 finished with value: -0.5811254566460788 and parameters: {'eps': 0.34326156895912036, 'min_samples': 5}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:44,341] Trial 8 finished with value: 0.6417940871979306 and parameters: {'eps': 0.7359351122714886, 'min_samples': 4}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:44,438] Trial 9 finished with value: 0.6616895400878501 and parameters: {'eps': 1.5126955744478614, 'min_samples': 6}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:44,578] Trial 10 finished with value: 0.6012598453208343 and parameters: {'eps': 1.9936634402578801, 'min_samples': 9}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:44,711] Trial 11 finished with value: 0.6616895400878501 and parameters: {'eps': 1.5619627381450107, 'min_samples': 9}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:44,837] Trial 12 finished with value: 0.6616895400878501 and parameters: {'eps': 1.5227240219430758, 'min_samples': 2}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:44,982] Trial 13 finished with value: 0.6012598453208343 and parameters: {'eps': 1.8830752997458002, 'min_samples': 8}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:45,120] Trial 14 finished with value: 0.6616895400878501 and parameters: {'eps': 1.3584135283819472, 'min_samples': 3}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:45,257] Trial 15 finished with value: 0.6012598453208343 and parameters: {'eps': 1.7533745117488126, 'min_samples': 8}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:45,391] Trial 16 finished with value: 0.6616895400878501 and parameters: {'eps': 1.183779437800663, 'min_samples': 4}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:45,534] Trial 17 finished with value: 0.6012598453208343 and parameters: {'eps': 1.6862197642840653, 'min_samples': 7}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:45,671] Trial 18 finished with value: 0.6548413105447543 and parameters: {'eps': 0.8531532256599316, 'min_samples': 10}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:45,769] Trial 19 finished with value: 0.6616895400878501 and parameters: {'eps': 1.384205020219848, 'min_samples': 3}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:45,872] Trial 20 finished with value: 0.6491079552511161 and parameters: {'eps': 0.9189476622490138, 'min_samples': 5}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:45,985] Trial 21 finished with value: 0.6616895400878501 and parameters: {'eps': 1.1137096376878566, 'min_samples': 7}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:46,097] Trial 22 finished with value: 0.6616895400878501 and parameters: {'eps': 1.281712080461224, 'min_samples': 5}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:46,228] Trial 23 finished with value: 0.5988851792168128 and parameters: {'eps': 1.0205136561271066, 'min_samples': 7}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:46,370] Trial 24 finished with value: 0.6616895400878501 and parameters: {'eps': 1.4219017668412124, 'min_samples': 3}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:46,420] Trial 25 finished with value: -1.0 and parameters: {'eps': 0.12069740378410332, 'min_samples': 5}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:46,528] Trial 26 finished with value: 0.6012598453208343 and parameters: {'eps': 1.6747861444914414, 'min_samples': 8}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:46,606] Trial 27 finished with value: 0.6616895400878501 and parameters: {'eps': 1.0711036123563862, 'min_samples': 6}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:46,695] Trial 28 finished with value: 0.6616895400878501 and parameters: {'eps': 1.286589383789468, 'min_samples': 4}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:46,856] Trial 29 finished with value: 0.6012598453208343 and parameters: {'eps': 1.8202163977755008, 'min_samples': 7}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:46,998] Trial 30 finished with value: 0.5988851792168128 and parameters: {'eps': 0.9769391110580183, 'min_samples': 6}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:47,135] Trial 31 finished with value: 0.6616895400878501 and parameters: {'eps': 1.226908611516387, 'min_samples': 2}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:47,265] Trial 32 finished with value: 0.6486371684108538 and parameters: {'eps': 0.7657907414124092, 'min_samples': 2}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:47,412] Trial 33 finished with value: 0.6616895400878501 and parameters: {'eps': 1.1214863247797828, 'min_samples': 3}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:47,547] Trial 34 finished with value: 0.6616895400878501 and parameters: {'eps': 1.615177937174106, 'min_samples': 2}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:47,679] Trial 35 finished with value: 0.5815163829459018 and parameters: {'eps': 0.6227703156005432, 'min_samples': 4}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:47,828] Trial 36 finished with value: 0.6616895400878501 and parameters: {'eps': 1.4616227210198007, 'min_samples': 5}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:47,966] Trial 37 finished with value: 0.6616895400878501 and parameters: {'eps': 1.3178792093446978, 'min_samples': 3}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:48,104] Trial 38 finished with value: 0.6616895400878501 and parameters: {'eps': 1.1907471027793983, 'min_samples': 6}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:48,230] Trial 39 finished with value: 0.4506851020451608 and parameters: {'eps': 0.5949797739426619, 'min_samples': 2}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:48,376] Trial 40 finished with value: 0.6616895400878501 and parameters: {'eps': 1.4869666686656693, 'min_samples': 5}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:48,517] Trial 41 finished with value: 0.6616895400878501 and parameters: {'eps': 1.5761828356073524, 'min_samples': 6}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:48,658] Trial 42 finished with value: 0.6616895400878501 and parameters: {'eps': 1.406658467127119, 'min_samples': 6}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:48,798] Trial 43 finished with value: 0.6616895400878501 and parameters: {'eps': 1.5235851154386328, 'min_samples': 4}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:48,941] Trial 44 finished with value: 0.6012598453208343 and parameters: {'eps': 1.8741589028797825, 'min_samples': 7}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:49,085] Trial 45 finished with value: 0.6012598453208343 and parameters: {'eps': 1.7339966417542587, 'min_samples': 8}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:49,230] Trial 46 finished with value: 0.6012598453208343 and parameters: {'eps': 1.9730102868442017, 'min_samples': 9}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:49,365] Trial 47 finished with value: 0.6616895400878501 and parameters: {'eps': 1.2375455905999844, 'min_samples': 4}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:49,508] Trial 48 finished with value: 0.6616895400878501 and parameters: {'eps': 1.6195396948214253, 'min_samples': 3}. Best is trial 1 with value: 0.6616895400878501.
# [I 2024-05-29 20:46:49,584] Trial 49 finished with value: 0.6491079552511161 and parameters: {'eps': 0.9185813678132448, 'min_samples': 5}. Best is trial 1 with value: 0.6616895400878501.

# %% [markdown]
# ### PLOTTING THE GRAPHS FOR BETTER VISUALIZATION FOR HYPER PARAMETERS

# %%
# Extract the results from the optimization studies
kmeans_results = study_kmeans.trials_dataframe()
agg_results = study_agg.trials_dataframe()
dbscan_results = study_dbscan.trials_dataframe()

# Plot the trade-off for K-Means
plt.figure(figsize=(10, 6))
plt.scatter(kmeans_results['params_n_clusters'], kmeans_results['value'], label='K-Means')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.title('Trade-off: Silhouette Score vs. Number of Clusters (K-Means)')
plt.legend()
plt.grid(True)
plt.show()

# Plot the trade-off for Agglomerative Clustering
plt.figure(figsize=(10, 6))
plt.scatter(agg_results['params_n_clusters'], agg_results['value'], label='Agglomerative Clustering')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.title('Trade-off: Silhouette Score vs. Number of Clusters (Agglomerative Clustering)')
plt.legend()
plt.grid(True)
plt.show()

# Plot the trade-off for DBSCAN
plt.figure(figsize=(10, 6))
plt.scatter(dbscan_results['params_eps'], dbscan_results['value'], label='DBSCAN')
plt.xlabel('EPS')
plt.ylabel('Silhouette Score')
plt.title('Trade-off: Silhouette Score vs. EPS (DBSCAN)')
plt.legend()
plt.grid(True)
plt.show()

# Plot the trade-off for K-Means (init and max_iter)
plt.figure(figsize=(10, 6))
plt.scatter(kmeans_results['params_init'], kmeans_results['value'], label='K-Means (init)', marker='o')
plt.xlabel('Initialization Method')
plt.ylabel('Silhouette Score')
plt.title('Trade-off: Silhouette Score vs. Initialization Method (K-Means)')
plt.legend()
plt.grid(True)
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(kmeans_results['params_max_iter'], kmeans_results['value'], label='K-Means (max_iter)', marker='o')
plt.xlabel('Maximum Iterations')
plt.ylabel('Silhouette Score')
plt.title('Trade-off: Silhouette Score vs. Maximum Iterations (K-Means)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### EVALUATION OF BEST PARAMETERS

# %%
# PRINTING THE HyperParameter(Best Params)
print("Best parameters for K-Means:", study_kmeans.best_trial.params)
print("Best parameters for Agglomerative Clustering:", study_agg.best_trial.params)
print("Best parameters for DBSCAN:", study_dbscan.best_trial.params)
# Out:
# Best parameters for K-Means: {'n_clusters': 5, 'init': 'k-means++', 'max_iter': 312}
# Best parameters for Agglomerative Clustering: {'n_clusters': 5}
# Best parameters for DBSCAN: {'eps': 1.4705204788249036, 'min_samples': 3}

# %% [markdown]
# ### APPLYING CLUSTERING WITH BEST PARAMTERS(generated from Trial-2):

# %%
# Apply clustering with the best parameters
# K-Means Clustering
kmeans = KMeans(n_clusters=5, init='random', max_iter=468, random_state=42)
cluster_labels_kmeans = kmeans.fit_predict(scaled_features)

# Agglomerative Clustering
agg_clustering = AgglomerativeClustering(n_clusters=5)
cluster_labels_ward = agg_clustering.fit_predict(scaled_features)

# DBSCAN
dbscan = DBSCAN(eps=1.2715365882144836, min_samples=2)
cluster_labels_dbscan = dbscan.fit_predict(scaled_features)

# Calculate Silhouette Scores
silhouette_kmeans = silhouette_score(scaled_features, cluster_labels_kmeans).round(3)
silhouette_agg = silhouette_score(scaled_features, cluster_labels_ward).round(3)
silhouette_dbscan = silhouette_score(scaled_features, cluster_labels_dbscan).round(3)

# %%
# Print the matrics
print(f"Silhouette Score (K-Means): {silhouette_kmeans}")
print(f"Silhouette Score (Agglomerative Clustering): {silhouette_agg}")
print(f"Silhouette Score (DBSCAN): {silhouette_dbscan}")
# Out:
# Silhouette Score (K-Means): 0.725
# Silhouette Score (Agglomerative Clustering): 0.725
# Silhouette Score (DBSCAN): 0.725

# %% [markdown]
# SCORE COMPARISION BETWEEN PRE and POST TRIALS Of HyperParameter Tuning:
# ----------------------------------------------------------------------------
#
#
# **Before best Paramater ( HyperParamater Tuning):**
#
# Silhouette Score (K-Means): 0.325
#
# Silhouette Score (Agglomerative): 0.314
#
# Silhouette Score (DBSCAN): 0.057
#
#
# **After Best Paramater(HyperParameter Tuning-1):**
#
# Silhouette Score (K-Means with Best Parameters): 0.336
#
# Silhouette Score (Agg_Clustering with Best Parameters): 0.914
#
# Silhouette Score (DBSCAN with Best Parameters): 0.244
#
# **After Best Paramater(HyperParamater Tuning-2):**
#
# Silhouette Score (K-Means): 0.725
#
# Silhouette Score (Agglomerative Clustering): 0.725
#
# Silhouette Score (DBSCAN): 0.725
#
# **Interpretation:**  HyperParamater Tuning-2 gives better score as compared to others

# %% [markdown]
# **Hyperparameter optimization to find the best parameters for three clustering algorithms and then applies these optimized models to assign cluster labels to the data points, allowing for cluster analysis and interpretation.**

# %%
# Apply K-Means with optimal parameters
kmeans_optimal = KMeans(n_clusters=study_kmeans.best_trial.params['n_clusters'],
                        init=study_kmeans.best_trial.params['init'],
                        max_iter=study_kmeans.best_trial.params['max_iter'])
kmeans_labels = kmeans_optimal.fit_predict(scaled_features)

# Apply Agglomerative Clustering with optimal parameters
agg_optimal = AgglomerativeClustering(n_clusters=study_agg.best_trial.params['n_clusters'])
agg_labels = agg_optimal.fit_predict(scaled_features)

# Apply DBSCAN with optimal parameters
dbscan_optimal = DBSCAN(eps=study_dbscan.best_trial.params['eps'],
                        min_samples=study_dbscan.best_trial.params['min_samples'])
dbscan_labels = dbscan_optimal.fit_predict(scaled_features)

# Add cluster labels to the original dataframe
features['KMeans_Cluster'] = kmeans_labels
features['Agglomerative_Cluster'] = agg_labels
features['DBSCAN_Cluster'] = dbscan_labels

# Explore the resulting clusters
print(features.groupby('KMeans_Cluster').mean())
print(features.groupby('Agglomerative_Cluster').mean())
print(features.groupby('DBSCAN_Cluster').mean())
# Out:
#                   degree  clustering  betweenness  closeness  \
# KMeans_Cluster
# 0              -2.488387    9.087855     4.697286   2.092693
# 1              -8.721795    8.883094     9.336007   6.118754
# 2              -0.880004    5.605308    -6.052219   0.279902
# 3               1.956265    4.283254    -9.670536   9.359898
# 4              -3.876932    0.335981    -1.483220  -4.263186
#
#                 avg_neighbor_degree  pagerank  2hop_degree  3hop_degree  \
# KMeans_Cluster
# 0                         -6.812091 -6.862927    -8.791863     7.289461
# 1                         -3.896547 -8.033832     3.665213    -1.150473
# 2                          1.930389 -9.119655     2.085272    -6.570834
# 3                          6.613805 -5.750637    -6.341089    -6.237033
# 4                          2.376105 -7.248471    -4.228970    -2.638641
#
#                 Agglomerative_Cluster  DBSCAN_Cluster
# KMeans_Cluster
# 0                                 0.0             2.0
# 1                                 3.0             1.0
# 2                                 1.0             3.0
# 3                                 2.0             4.0
# 4                                 4.0             0.0
#                          degree  clustering  betweenness  closeness  \
# Agglomerative_Cluster
# 0                     -2.488387    9.087855     4.697286   2.092693
# 1                     -0.880004    5.605308    -6.052219   0.279902
# 2                      1.956265    4.283254    -9.670536   9.359898
# 3                     -8.721795    8.883094     9.336007   6.118754
# 4                     -3.876932    0.335981    -1.483220  -4.263186
#
#                        avg_neighbor_degree  pagerank  2hop_degree  \
# Agglomerative_Cluster
# 0                                -6.812091 -6.862927    -8.791863
# 1                                 1.930389 -9.119655     2.085272
# 2                                 6.613805 -5.750637    -6.341089
# 3                                -3.896547 -8.033832     3.665213
# 4                                 2.376105 -7.248471    -4.228970
#
#                        3hop_degree  KMeans_Cluster  DBSCAN_Cluster
# Agglomerative_Cluster
# 0                         7.289461             0.0             2.0
# 1                        -6.570834             2.0             3.0
# 2                        -6.237033             3.0             4.0
# 3                        -1.150473             1.0             1.0
# 4                        -2.638641             4.0             0.0
#                   degree  clustering  betweenness  closeness  \
# DBSCAN_Cluster
# 0              -3.876932    0.335981    -1.483220  -4.263186
# 1              -8.721795    8.883094     9.336007   6.118754
# 2              -2.488387    9.087855     4.697286   2.092693
# 3              -0.880004    5.605308    -6.052219   0.279902
# 4               1.956265    4.283254    -9.670536   9.359898
#
#                 avg_neighbor_degree  pagerank  2hop_degree  3hop_degree  \
# DBSCAN_Cluster
# 0                          2.376105 -7.248471    -4.228970    -2.638641
# 1                         -3.896547 -8.033832     3.665213    -1.150473
# 2                         -6.812091 -6.862927    -8.791863     7.289461
# 3                          1.930389 -9.119655     2.085272    -6.570834
# 4                          6.613805 -5.750637    -6.341089    -6.237033
#
#                 KMeans_Cluster  Agglomerative_Cluster
# DBSCAN_Cluster
# 0                          4.0                    4.0
# 1                          1.0                    3.0
# 2                          0.0                    0.0
# 3                          2.0                    1.0
# 4                          3.0                    2.0

# %% [markdown]
# ### STEP:7-2: Interpretation and Analysis of Cluster data

# %% [markdown]
# ### K-Means Clustering
#
# 1. **Cluster 0:**
#
# Degree: Low ,
# Clustering: High,
# Betweenness: Moderate,
# Closeness: Low,
# Average Neighbor Degree: Low,
# Pagerank: Low ,
# 2-hop Degree: Low,
# 3-hop Degree: High
#
# **Interpretation:**
#
# Nodes in this cluster tend to have lower connectivity but high local clustering. They are not central (low betweenness) but have a high influence in their local neighborhood (high 3-hop degree).
#
# **2. Cluster 1:**
#
# Degree: Very Low,
# Clustering: High,
# Betweenness: High,
# Closeness: High,
# Average Neighbor Degree: Low,
# Pagerank: Very Low,
# 2-hop Degree: Moderate,
# 3-hop Degree: Low,
#
# **Interpretation:**
#
# These nodes are crucial connectors in the network (high betweenness and closeness) but are not necessarily connected to many other nodes (low degree).
#
#
# **3. Cluster 2:**
#
# Degree: Moderate,
# Clustering: Moderate,
# Betweenness: Very Low ,
# Closeness: Very Low ,
# Average Neighbor Degree: High ,
# Pagerank: Very Low ,
# 2-hop Degree: Moderate,
# 3-hop Degree: Very Low,
#
# **Interpretation:**
#
# This cluster represents nodes with a moderate number of connections and a medium clustering coefficient. They have low centrality and influence (low betweenness and pagerank).
#
# **3. Cluster 3:**
#
# Degree: High,
# Clustering: Moderate,
# Betweenness: Very Low,
# Closeness: High,
# Average Neighbor Degree: High,
# Pagerank: Low,
# 2-hop Degree: Very Low,
# 3-hop Degree: Very Low,
#
# Interpretation:
#
# Nodes in this cluster are highly connected (high degree) with moderate local clustering. They are well-connected in the network (high closeness) but have low influence beyond their immediate connections (low betweenness and pagerank).
#
# **4. Cluster 4:**
#
# Degree: Low,
# Clustering: Very Low,
# Betweenness: Low,
# Closeness: Low,
# Average Neighbor Degree: Moderate,
# Pagerank: Low,
# 2-hop Degree: Low,
# 3-hop Degree: Low,
#
# **Interpretation:**
#
# These nodes are sparsely connected with very low local clustering. They are not central or influential in the network.

# %% [markdown]
# ### Agglomerative Clustering
# The results for Agglomerative Clustering are quite similar to K-Means, suggesting the robustness of the clusters:
#
# **Cluster 0:**
#   Similar characteristics to K-Means Cluster 0.
#
# **Cluster 1:**
#    Similar characteristics to K-Means Cluster 2.
#
# **Cluster 2:**
#   Similar characteristics to K-Means Cluster 3.
#
# **Cluster 3:**
# Similar characteristics to K-Means Cluster 1.
#
# **Cluster 4:**
# Similar characteristics to K-Means Cluster 4.

# %% [markdown]
# ### DBSCAN Clustering:
#
# **Cluster 0:**
#   Similar to K-Means Cluster 4.
#
# **Cluster 1:**
# Similar to K-Means Cluster 1.
#
# **Cluster 2:**
# Similar to K-Means Cluster 0.
#
# **Cluster 3:**
# Similar to K-Means Cluster 2.
#
# **Cluster 4:**
#   Similar to K-Means Cluster 3.

# %% [markdown]
# ##General Insights:
#
# *   Consistency Across Algorithms: The clusters identified by K-Means, Agglomerative Clustering, and DBSCAN are largely consistent, indicating stable and robust clusters.
# *   Cluster Characteristics:
#   * Low pagerank values across many clusters suggest that only a few nodes are significantly influential in terms of link structure.
#
#   *   High clustering coefficient nodes are typically less central but can form tightly-knit groups.
#   *   Nodes with high betweenness are crucial connectors or bridges within the network.
#   *    Nodes with high degree and closeness are well-connected and central in the network.
#
# ## Business insights that can be drawn:
#
# **Users Segmentation:**
#
# *   Use clusters to segment your audience based on network roles and connectivity.
# *  Target highly connected clusters (e.g., Cluster 3) for broad outreach and engagement campaigns.
#
# **Identifying Influencers:**
#
# *  Focus on nodes in clusters with high betweenness and closeness (e.g., Cluster 1) for influencer marketing.
# *   These users can amplify your message due to their strategic position in the network.
#
# **Community Engagement:**
#
# * Engage with tightly-knit communities (e.g., Cluster 0) for building brand loyalty and trust.
# * Tailing  engagement strategies to different clusters based on their network characteristics.

# %% [markdown]
# ### STEP:7-3: Final Interpretation and Cluster Analysis with insights

# %%
# Standardize the features
"""
Doing Scaling because some clustering techniques mights be sensitive to feature scaling.
Sensitivity of a clustering algorithm refers to how its performance or output is influenced by the scale or magnitude of the input features
"""
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Apply clustering with the best parameters
# K-Means Clustering
kmeans = KMeans(n_clusters=5, init='k-means++', max_iter=468, random_state=42)
cluster_labels_kmeans = kmeans.fit_predict(scaled_features)

# Agglomerative Clustering
agg_clustering = AgglomerativeClustering(n_clusters=5)
cluster_labels_ward = agg_clustering.fit_predict(scaled_features)

# DBSCAN
dbscan = DBSCAN(eps=1.2715365882144836, min_samples=2)
cluster_labels_dbscan = dbscan.fit_predict(scaled_features)

# Apply PCA to reduce to 2 dimensions for visualization
pca = PCA(n_components=2)
pca_features = pca.fit_transform(scaled_features)

# Create a DataFrame with the PCA features and the cluster labels
pca_df = pd.DataFrame(pca_features, columns=['PCA1', 'PCA2'])
pca_df['KMeans_Cluster'] = cluster_labels_kmeans
pca_df['Agglomerative_Cluster'] = cluster_labels_ward
pca_df['DBSCAN_Cluster'] = cluster_labels_dbscan

# Plotting function for each clustering algorithm with annotations
def plot_clusters(df, cluster_column, title):
    plt.figure(figsize=(10, 6))
    unique_clusters = df[cluster_column].unique()
    palette = sns.color_palette('viridis', len(unique_clusters))

    sns.scatterplot(x='PCA1', y='PCA2', hue=cluster_column, data=df, palette=palette, s=100, alpha=0.6, legend=False)

    # Annotate each cluster center
    for cluster in unique_clusters:
        cluster_data = df[df[cluster_column] == cluster]
        cluster_center = cluster_data[['PCA1', 'PCA2']].mean().values
        plt.annotate(f'Cluster {cluster}', cluster_center, fontsize=12, weight='bold',
                     horizontalalignment='center', verticalalignment='center',
                     bbox=dict(facecolor='white', alpha=0.5, edgecolor='black'))

    plt.title(title)
    plt.grid(True)
    plt.show()

# Plot the clusters for each algorithm
plot_clusters(pca_df, 'KMeans_Cluster', 'K-Means Clustering')
plot_clusters(pca_df, 'Agglomerative_Cluster', 'Agglomerative Clustering')
plot_clusters(pca_df, 'DBSCAN_Cluster', 'DBSCAN Clustering')

# %%
# Add cluster labels to the original dataframe to gain insights
features['KMeans_Cluster'] = cluster_labels_kmeans
features['Agglomerative_Cluster'] = cluster_labels_ward
features['DBSCAN_Cluster'] = cluster_labels_dbscan

# Explore the resulting clusters
print(features.groupby('KMeans_Cluster').mean())
print(features.groupby('Agglomerative_Cluster').mean())
print(features.groupby('DBSCAN_Cluster').mean())
# Out:
#                   degree  clustering  betweenness  closeness  \
# KMeans_Cluster
# 0               1.956265    4.283254    -9.670536   9.359898
# 1              -8.721795    8.883094     9.336007   6.118754
# 2              -3.876932    0.335981    -1.483220  -4.263186
# 3              -2.488387    9.087855     4.697286   2.092693
# 4              -0.880004    5.605308    -6.052219   0.279902
#
#                 avg_neighbor_degree  pagerank  2hop_degree  3hop_degree  \
# KMeans_Cluster
# 0                          6.613805 -5.750637    -6.341089    -6.237033
# 1                         -3.896547 -8.033832     3.665213    -1.150473
# 2                          2.376105 -7.248471    -4.228970    -2.638641
# 3                         -6.812091 -6.862927    -8.791863     7.289461
# 4                          1.930389 -9.119655     2.085272    -6.570834
#
#                 Agglomerative_Cluster  DBSCAN_Cluster
# KMeans_Cluster
# 0                                 3.0             4.0
# 1                                 1.0             1.0
# 2                                 4.0             0.0
# 3                                 0.0             2.0
# 4                                 2.0             3.0
#                          degree  clustering  betweenness  closeness  \
# Agglomerative_Cluster
# 0                     -2.488387    9.087855     4.697286   2.092693
# 1                     -8.721795    8.883094     9.336007   6.118754
# 2                     -0.880004    5.605308    -6.052219   0.279902
# 3                      1.956265    4.283254    -9.670536   9.359898
# 4                     -3.876932    0.335981    -1.483220  -4.263186
#
#                        avg_neighbor_degree  pagerank  2hop_degree  \
# Agglomerative_Cluster
# 0                                -6.812091 -6.862927    -8.791863
# 1                                -3.896547 -8.033832     3.665213
# 2                                 1.930389 -9.119655     2.085272
# 3                                 6.613805 -5.750637    -6.341089
# 4                                 2.376105 -7.248471    -4.228970
#
#                        3hop_degree  KMeans_Cluster  DBSCAN_Cluster
# Agglomerative_Cluster
# 0                         7.289461             3.0             2.0
# 1                        -1.150473             1.0             1.0
# 2                        -6.570834             4.0             3.0
# 3                        -6.237033             0.0             4.0
# 4                        -2.638641             2.0             0.0
#                   degree  clustering  betweenness  closeness  \
# DBSCAN_Cluster
# 0              -3.876932    0.335981    -1.483220  -4.263186
# 1              -8.721795    8.883094     9.336007   6.118754
# 2              -2.488387    9.087855     4.697286   2.092693
# 3              -0.880004    5.605308    -6.052219   0.279902
# 4               1.956265    4.283254    -9.670536   9.359898
#
#                 avg_neighbor_degree  pagerank  2hop_degree  3hop_degree  \
# DBSCAN_Cluster
# 0                          2.376105 -7.248471    -4.228970    -2.638641
# 1                         -3.896547 -8.033832     3.665213    -1.150473
# 2                         -6.812091 -6.862927    -8.791863     7.289461
# 3                          1.930389 -9.119655     2.085272    -6.570834
# 4                          6.613805 -5.750637    -6.341089    -6.237033
#
#                 KMeans_Cluster  Agglomerative_Cluster
# DBSCAN_Cluster
# 0                          2.0                    4.0
# 1                          1.0                    1.0
# 2                          3.0                    0.0
# 3                          4.0                    2.0
# 4                          0.0                    3.0

# %% [markdown]
# ## VISUALISATIONS FOR THE ABOVE OUPUT(CLUSTER DATA):-

# %%
# Plotting cluster means for each feature without annoations
fig, axes = plt.subplots(3, 1, figsize=(12, 12))

# K-Means Clustering
features.groupby('KMeans_Cluster').mean().plot(kind='bar', ax=axes[0], title='K-Means Clustering')

# Agglomerative Clustering
features.groupby('Agglomerative_Cluster').mean().plot(kind='bar', ax=axes[1], title='Agglomerative Clustering')

# DBSCAN
features.groupby('DBSCAN_Cluster').mean().plot(kind='bar', ax=axes[2], title='DBSCAN Clustering')

plt.tight_layout()
plt.show()

# %%
# Plotting cluster means for each feature with annotations
fig, axes = plt.subplots(3, 1, figsize=(12, 12))

# Function to add annotations to the bars
def add_annotations(ax):
    for p in ax.patches:
        ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', fontsize=10, xytext=(0, 10), textcoords='offset points')

# K-Means Clustering
kmeans_means = features.groupby('KMeans_Cluster').mean()
kmeans_means.plot(kind='bar', ax=axes[0], title='K-Means Clustering')
add_annotations(axes[0])

# Agglomerative Clustering
agg_means = features.groupby('Agglomerative_Cluster').mean()
agg_means.plot(kind='bar', ax=axes[1], title='Agglomerative Clustering')
add_annotations(axes[1])

# DBSCAN
dbscan_means = features.groupby('DBSCAN_Cluster').mean()
dbscan_means.plot(kind='bar', ax=axes[2], title='DBSCAN Clustering')
add_annotations(axes[2])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### FINAL OBSERVATIONS:
#
# **General Insights:**
#
#   * **Consistency Across Algorithms:**
#
#       Clusters identified by K-Means, Agglomerative Clustering, and DBSCAN are consistent, indicating stable groupings within the network.Consistency across algorithms provides confidence in the identified clusters.
#   * **Cluster Characteristics:**
#     1. Nodes with low pagerank values are less influential, while high clustering coefficient nodes form tightly-knit groups.
#     2. Nodes with high betweenness are crucial connectors, while high degree and closeness centrality indicate well-connected and central nodes.
#
# **Business Insights can be drawn:**
#
#   1. **User Segmentation:**
#       Segmenting the users  based on network roles and connectivity can inform targeted outreach campaigns.
#
#   2. **Identifying Influencers:**
#       Nodes with high betweenness and closeness centrality are potential influencers for amplifying messages. Engage with influential users to initiate brand advocacy programs, encouraging them to share positive experiences and endorse products or services within their communities
#   3. **Community Engagement:**
#       Engaging with tightly-knit communities can foster brand loyalty and trust.
